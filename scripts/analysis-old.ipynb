# %%
# Import Dependencies

from time import sleep
from mido import MidiFile
import pandas as pd

from datetime import date
from time import time, monotonic
from os import path, mkdir, listdir, environ
import subprocess

from tqdm import tqdm

# %%
# Get Args, define evaluation groups

iterations = 4        # How many times each experiment should be repeated for the same parameters?
min_input_bars = 1    # What is the minimum lookback size for each model?
min_output_bars = 1   # What is the minimum output size for each model?

max_input_bars = 5    # What is the maximum lookback size for each model?
max_output_bars = 5   # What is the maximum output size for each model?
sample_length = 8     # How long of a final composition should be generated?
ignore = (            # What models to ignore during generation/analysis
  [ 'music_transformer'
  
  # FIXME: These are temporary - shit went wrong
  , 'rl_duet'            
  # , 'pianoroll_rnn_nade'
  # , 'polyphony_rnn'
  # , 'melody_rnn'
  , 'performance_rnn'
  ] 
)
modelname = None
checkpointname = None


# FIXME: Remove this
iterations = 4
max_input_bars = 5
max_output_bars = 5
sample_length = 4


# Evaluated Model Table
eval_columns = (
    ['model'               , 'dataset'       , 'output_tracks' , 'checkpoint']
)
eval_list = (
  [ ['performance_rnn'     , 'piano-e-comp'  , None            , 'performance_with_dynamics']
  , ['performance_rnn'     , 'piano-e-comp'  , None            , 'density_conditioned_performance_with_dynamics']
  , ['performance_rnn'     , 'piano-e-comp'  , None            , 'pitch_conditioned_performance_with_dynamics']
  , ['performance_rnn'     , 'piano-e-comp'  , None            , 'multiconditioned_performance_with_dynamics']
  , ['performance_rnn'     , 'piano-e-comp'  , None            , 'performance_with_dynamics_and_modulo_encoding']
  , ['rl_duet'             , 'bach10'        , None            , 'rl_duet']
  , ['pianoroll_rnn_nade'  , 'bach10'        , None            , 'rnn-nade_attn']

  # TODO: MelodyRNN 
  , ['melody_rnn'          , 'mtd-orig'      , None            , 'basic_rnn']
  , ['melody_rnn'          , 'mtd-orig'      , None            , 'mono_rnn']
  , ['melody_rnn'          , 'mtd-orig'      , None            , 'attention_rnn']
  , ['melody_rnn'          , 'mtd-orig'      , None            , 'lookback_rnn']
  , ['polyphony_rnn'       , 'bach10'        , None            , 'polyphony_rnn']
  , ['pianoroll_rnn_nade'  , 'bach10'        , None            , 'rnn-nade_attn']
  , ['music_transformer'   , 'piano-e-comp'  , None            , 'performance_with_dynamics']
  ]
)
eval_list = pd.DataFrame(eval_list, columns=eval_columns)

# Filter ignored models
for ignored_model in ignore:
  eval_list = eval_list[eval_list['model'] != ignored_model]

# Index table with dataset names
evaluation_sets = [
  (dataset, [ (modelname, checkpoint, output_tracks)
    for [modelname, checkpoint, output_tracks]
    in inner_df[['model', 'checkpoint', 'output_tracks']].values 
  ])
  for dataset, inner_df in eval_list.groupby(['dataset'])
]

cols_gen = [ "model", "checkpoint", "dataset", "primer", "iteration", "out_file", "time", "in_len", "out_len" ]

# %%
# # Folder Definitions (+ Create new folder)
# outputdir = path.join(path.curdir,'output')
# datasetdir = path.join(path.curdir,'dataset')
# basefoldername = str(date.today())
# i = 0
# while True:
#     foldername = f'{basefoldername}-{i}'
#     full_foldername = path.join(outputdir, foldername)

#     if not path.exists(full_foldername):
#       mkdir(full_foldername)
#       break

#     if not any(listdir(full_foldername)): break
#     i = i + 1

# expname = ''
# def log(message):
#     print(f'[batch:{expname}] {message}')

# %%
# Generation Methods

from functools import reduce
import re
import math

# Prepare a command string to send to ornette via CLI
def escape_command(commands):
  commands = re.split('\n|;', commands)
  commands = [line.split(' ') for line in commands]
  commands = [cmd for cmd in commands if any(cmd)]
  commands = ['\ '.join(line) for line in commands]
  commands = '\;'.join(commands)
  return commands

def get_filename(modelname, checkpointname, primer, index, bars_input, bars_output):
  return f'{foldername}/{modelname}-{checkpointname}-{index}-{bars_input}-{bars_output}-{primer}'

# WIP: another approach, via CLI args
def get_generation_command(the_modelname, the_checkpointname, output_tracks, datapath, primer, bars_input, bars_output, count):
  total_song_barcount = bars_input + sample_length
  gen_steps = math.ceil(sample_length / bars_output)
  
  # Main generation loop
  exec_cmd = ';\n'.join([f'generate {bars_output} bars' for i in range(gen_steps) ])

  # Reset, load the primer again, generate, save
  exec_cmd = [';\n'.join(
      [ 'reset'
      , f'load {datapath}/{primer} {bars_input}'
      , exec_cmd
      , f'crop bars {bars_input} {total_song_barcount}'
      , f'save {get_filename(the_modelname, the_checkpointname, primer, index, bars_input, bars_output)}'
      , 'end'
      ]
    )
    for index
    in range(count)]
  
  # Before running generation: set variables
  exec_vars = [ 'set debug_output True;'
    , 'set batch_mode True;'
    , 'set playback False;'
    # , 'set trigger_generate 1;'
    , 'set batch_unit measures;'
    , 'set debug_output False;'
    , f'set input_length {bars_input};'
    , f'set input_unit bars;'
    , f'set output_length {bars_output};'
    , f'set output_unit bars;'
  ]

  if output_tracks: exec_vars.append('set output_tracks ' + output_tracks + ';')

  # Combine Lines
  exec_cmd = '\n'.join(exec_vars + exec_cmd)

  # Escape string to pass it via CLI
  exec_cmd = escape_command(exec_cmd)
  return exec_cmd

logfile = None
def generate_samples(the_modelname, the_checkpointname, output_tracks, datapath, primer, bars_input, bars_output, count, t):
    customprint = t.set_description if t else log
    # Set logging prefix
    modelname = the_modelname
    checkpointname = the_checkpointname
    t.set_description(f'Generating ({modelname}:{checkpointname}) samples with {primer}')

    # Get Ornette CLI command
    if datapath.startswith('.'): datapath = datapath[1:]
    cmd = get_generation_command(the_modelname, the_checkpointname, output_tracks, datapath, primer, bars_input, bars_output, count)

    # Process filenames
    filenames = [get_filename(the_modelname, the_checkpointname, primer, index, bars_input, bars_output) for index in range(count)]


    # Run (and time) the generation batch
    env = environ.copy()
    logfilename = path.join(outputdir, f'{the_modelname}-{the_checkpointname}.log')
    logfile = open(logfilename, 'a')

    start_time = monotonic()
    server = subprocess.run(
      ['python' , '.' , '--modelname' , modelname , '--checkpoint' , checkpoint , '--exec' , cmd , '--no-server=True']
      , env=env
      , stdout=logfile
      , stderr=logfile
      )
    end_time = monotonic()
    
    # Calculate total generation time
    gentime = end_time - start_time
    return [(filenames, gentime)]

def run_generation(model, checkpoint, datapath, primers, output_tracks):
  logfilename = path.join(outputdir, f'{model}-{checkpoint}.log')
  with open(logfilename,'w') as logfile:
    print('\n', file=logfile)
  
    t = tqdm([ model
    , checkpoint
    , dataset
    , primer
    , iterations # TODO: pass iterations to generate samples / use iterations here
    # , *generate_samples(model, checkpoint, datapath, primer, bars_input, bars_output, iterations)
    , filename
    , gentime
    , bars_input
    , bars_output
    ]
    for bars_input in range(min_input_bars,max_input_bars + 1)
    for bars_output in range(min_output_bars,max_output_bars + 1)
    for primer in primers
    for (filenames, gentime) in generate_samples(model, checkpoint, output_tracks, datapath, primer, bars_input, bars_output, iterations, t)
    for filename in filenames)
  
  # filenames, gentime = generate_samples(model, checkpoint, datapath, primer, bars_input, bars_output, iterations)
  return list(t)

# %%
# Generation Phase

import pickle
import random

max_primers = None
max_primers = 10

try:
    tqdm.write(f'Starting experiment suite: {outputdir}/{foldername}')

    # Set logging prefix
    output = []
    for dataset, models in evaluation_sets:
        if dataset is None: continue
        datapath = path.join(datasetdir, dataset)
        primerdir = datapath
        if not path.exists(datapath):
            # print(f'Directory not found: {datapath}, skipping')
            continue

        # TODO; Pick N samples randomly from the dataset
        # primers = random.shuffle(listdir(datapath))
        primers = listdir(datapath)
        if max_primers: primers = primers[:max_primers]

        # Run a generation bath with the chosen samples
        for (model, checkpoint, output_tracks) in models:
            expname = model
            e = run_generation(model, checkpoint, datapath, primers, output_tracks)
            output += e
    
    # Create DataFrame
    df = pd.DataFrame(output, columns=cols_gen)
    df.to_pickle(path.join(outputdir, 'df_gen'))
    

except KeyboardInterrupt:
  tqdm.write("Terminating...")

tqdm.write("Done!")
# Out:
# n', 'lookback_rnn', 'bach10', '04-ChristeDuBeistand.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-3-5-2-04-ChristeDuBeistand.mid', 12.836111840908416, 5, 2], ['melody_rnn', 'lookback_rnn', 'bach10', '02-AchLiebenChristen.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-0-5-3-02-AchLiebenChristen.mid', 20.422546992078424, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '02-AchLiebenChristen.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-1-5-3-02-AchLiebenChristen.mid', 20.422546992078424, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '02-AchLiebenChristen.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-2-5-3-02-AchLiebenChristen.mid', 20.422546992078424, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '02-AchLiebenChristen.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-3-5-3-02-AchLiebenChristen.mid', 20.422546992078424, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '01-AchGottundHerr.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-0-5-3-01-AchGottundHerr.mid', 18.102101798984222, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '01-AchGottundHerr.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-1-5-3-01-AchGottundHerr.mid', 18.102101798984222, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '01-AchGottundHerr.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-2-5-3-01-AchGottundHerr.mid', 18.102101798984222, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '01-AchGottundHerr.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-3-5-3-01-AchGottundHerr.mid', 18.102101798984222, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '07-HerrGott.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-0-5-3-07-HerrGott.mid', 13.549424209049903, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '07-HerrGott.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-1-5-3-07-HerrGott.mid', 13.549424209049903, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '07-HerrGott.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-2-5-3-07-HerrGott.mid', 13.549424209049903, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '07-HerrGott.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-3-5-3-07-HerrGott.mid', 13.549424209049903, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '08-FuerDeinenThron.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-0-5-3-08-FuerDeinenThron.mid', 12.46028912300244, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '08-FuerDeinenThron.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-1-5-3-08-FuerDeinenThron.mid', 12.46028912300244, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '08-FuerDeinenThron.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-2-5-3-08-FuerDeinenThron.mid', 12.46028912300244, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '08-FuerDeinenThron.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-3-5-3-08-FuerDeinenThron.mid', 12.46028912300244, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '05-DieNacht.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-0-5-3-05-DieNacht.mid', 19.04216298297979, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '05-DieNacht.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-1-5-3-05-DieNacht.mid', 19.04216298297979, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '05-DieNacht.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-2-5-3-05-DieNacht.mid', 19.04216298297979, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '05-DieNacht.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-3-5-3-05-DieNacht.mid', 19.04216298297979, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '09-Jesus.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-0-5-3-09-Jesus.mid', 17.033785269013606, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '09-Jesus.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-1-5-3-09-Jesus.mid', 17.033785269013606, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '09-Jesus.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-2-5-3-09-Jesus.mid', 17.033785269013606, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '09-Jesus.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-3-5-3-09-Jesus.mid', 17.033785269013606, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '10-NunB ...
#        iteration         time      in_len     out_len
# count     4000.0  4000.000000  4000.00000  4000.00000
# mean         4.0    18.815326     3.00000     3.00000
# std          0.0    11.833313     1.41439     1.41439
# min          4.0     6.667986     1.00000     1.00000
# 25%          4.0    11.125446     2.00000     2.00000
# 50%          4.0    14.192724     3.00000     3.00000
# 75%          4.0    21.933120     4.00000     4.00000
# max          4.0    77.579515     5.00000     5.00000
# Done!

# %%
# Filter Data
import pandas as pd
df_gen = pd.read_pickle('output/df_gen')
df_gen.to_pickle(path.fjoin(outputdir, 'df_gen_bk'))

# Get Models
def get_models(df_):
    df_['uniquename'] = df_['model'] + ':' + df_['checkpoint']
    uniques = [x for x in df_['uniquename'].unique()]
    return uniques

# Only where an output file exists
df_success = df_gen[df_gen.apply(lambda x: os.path.exists(f'output/{x["out_file"]}.mid'),axis=1)]

# print(newdf)
err = [name for name
  in get_models(df_gen)
  if name not in get_models(df_success)
  ]

if any(err):
    df_success.to_pickle(path.join(outputdir, 'df_gen'))
    print(f'The following models had problems at generation time and will not be analysed: {", ".join(err)}')
else:
  print("DataFrame checked!")
# Out:
# DataFrame checked!

# %%
# Baseline Generaion Phase

# TODO (New Branch)
# 1. define commands
# 2. define directories
# 3. bind commands to models
# 4. run commands
# 5. Cell below:
#   - update cmd_extraction command
#   - create run_script() command
#   - define scripts in new cell (maybe)

# Split Cells:
# Generate Baseline samples
#  - Crop input (dataset) sequences to temporary folder
#  - Generate baseline samples
#  - Save to output folder (might need cropping)
# 1. Preprocess output and :max_primers from dataset onto new folders (preprocessed/{dataset,}))
# 3. Evaluate - baseline and generated

# %%
# Analysis Stage

import os
import subprocess
import glob
import json
import pandas as pd
from itertools import islice, cycle
outputdir = os.path.abspath(os.path.join(os.curdir, 'output'))
df_gen = pd.read_pickle(os.path.join(outputdir, 'df_gen'))
metricsfile = os.path.join(outputdir, 'metrics')

# Define Directories
output_samples_dir  = os.path.join(outputdir, 'samples')
output_dataset_dir  = os.path.join(outputdir, 'dataset')
datadirs = [ output_samples_dir, output_dataset_dir ]

# Define External Commands (Scripts)
extraction_scriptdir = os.path.abspath(os.path.join(os.path.pardir, 'mgeval'))
extraction_script = os.path.join(extraction_scriptdir, 'start.sh') 
# TODO: Change this to receive samples dir (output_samples_dir / baseline_samples_dir)
cmd_extraction = [ 'bash', extraction_script, output_samples_dir, output_dataset_dir, metricsfile, str(sample_length) ]

preprocess_scriptdir = os.path.abspath(os.path.join(os.path.pardir, 'miditools'))
preprocess_script = os.path.join(preprocess_scriptdir, 'midisox_py')
cmd_preprocess = lambda _in, _out: [ 'python', preprocess_script, '-m', os.path.abspath(_in), os.path.abspath(_out) ]

# Prepare output log file
logfile = open(path.join(outputdir, f'analysis.log'), 'w')

# Prepare Metrics DF
df_metrics = df_gen

# Prepare Output Data Fields
metriccolumns = ['model', 'checkpoint', 'in_len', 'out_len', 'iteration']
metrics_initialized = False
out = []

# Iterate combinations of input/output windows
grouping = df_metrics.groupby(['model', 'checkpoint', 'in_len', 'out_len', 'dataset', 'iteration'])
t = tqdm(grouping.out_file)
for (model, checkpoint, inn, outn, dataset, iteration), outfiles in t:
    # if model == 'melody_rnn': continue
    expname = model
    t.set_description(f'{model}:{checkpoint}')

    for _dir in datadirs:
        # Check that directory exists
        if not os.path.exists(_dir):
            os.mkdir(_dir)

        # Clean output directory
        for file in glob.glob(os.path.join(_dir,'*')):
            if not os.path.exists(file): continue
            if os.path.islink(file): os.unlink(file)
            else: os.remove(file)

    # Remove previous metrics file if any (for sanity)
    if os.path.exists(metricsfile):
        os.remove(metricsfile)

    # Prepare Dataset Samples
    dataset_samples = glob.glob(os.path.join(os.path.curdir, 'dataset', dataset, '*')) # Get all files in dataset folder
    total_effective_samples = len(outfiles.unique())                                   # Count how many samples were actually generated
    dataset_samples = list(islice(cycle(dataset_samples),total_effective_samples))     # Get exactly that same count, repeating if necessary
    
    # Preprocess Dataset Samples
    for index, filename in enumerate(dataset_samples):
        out_filename = os.path.join(outputdir, 'dataset', f'sample-{index}.mid')
        subprocess.call(cmd_preprocess(filename, out_filename), stdout=logfile, stderr=logfile, cwd=preprocess_scriptdir)
    
    # Prepare Output Samples 
    for o, outfile in enumerate(outfiles.unique()):

        # Create link to file
        in_filename = os.path.abspath(os.path.join("output", f"{outfile}.mid"))
        out_filename = os.path.abspath(os.path.join(output_samples_dir, f'sample-{o}.mid'))
        subprocess.call(cmd_preprocess(in_filename, out_filename), stdout=logfile, stderr=logfile, cwd=preprocess_scriptdir)

    # Extract Features
    subprocess.call(cmd_extraction, stdout=logfile, stderr=logfile, cwd=extraction_scriptdir)

    # Read Extracted features
    with open(metricsfile, 'r') as metricsfile_:
        row_metrics = json.load(metricsfile_)

    # Initialize Metrics (if necessary)
    if not metrics_initialized:
        metrics_initialized = True
        for metric in row_metrics.keys():
            metriccolumns.extend([metric + '_kl_div', metric + '_overlap'])
    

    row = [model, checkpoint, inn, outn, iteration]
    # print(row_metrics)
    for metric in row_metrics.keys():
        [_mean, _std, _kl_div, _overlap, _training_set_kl_div, _training_set_overlap] = row_metrics[metric]
        row.extend([ _kl_div, _overlap ])
    out.append(row.copy())

logfile.close()

# Save values to output DF
print(pd.DataFrame(out, columns=metriccolumns))
df = df_metrics.merge(pd.DataFrame(out, columns=metriccolumns), how='inner', on=['model', 'checkpoint', 'in_len', 'out_len', 'iteration'])

df.to_pickle(path.join(outputdir, 'df_metrics'))
# Out:
#         0.248195
# 72               0.039656            1.859408e-02                0.077838
# 73               0.074419            7.548353e-02                0.139788
# 74               0.028216            1.171588e-01                0.207060
# 75               0.128592            1.115185e-05                0.120750
# 76               0.064160            2.076106e-03                0.192463
# 77               0.026796            1.147979e-03                0.138274
# 78               0.036803            3.405949e-02                0.109347
# 79               0.051579            3.487877e-02                0.176526
# 80               0.114726            1.805345e-09                0.080562
# 81               0.089697            4.634709e-05                0.072702
# 82               0.025410            1.574313e-03                0.287288
# 83               0.039360            5.651967e-02                0.311329
# 84               0.029420            9.304788e-02                0.124960
# 85               0.292149            2.890691e-16                0.191238
# 86               0.200382            4.577551e-04                0.286749
# 87               0.021771            5.545506e-03                0.262843
# 88               0.043114            6.478296e-02                0.271085
# 89               0.094062            1.081986e-01                0.129637
# 90               0.260012            1.114708e-05                0.093117
# 91               0.041256            1.580714e-03                0.186285
# 92               0.083487            6.001375e-02                0.248972
# 93               0.031295            8.492432e-02                0.146129
# 94               0.053248            1.057090e-01                0.113281
# 95               0.238566            9.104799e-13                0.112738
# 96               0.108421            3.285559e-04                0.131889
# 97               0.045231            1.231377e-02                0.335452
# 98               0.003065            1.138980e-01                0.224989
# 99               0.066394            1.349017e-01                0.242792
#
#     ...  bar_used_note_kl_div  bar_used_note_overlap  avg_pitch_shift_kl_div  \
# 0   ...              0.248536               0.000345                0.036400
# 1   ...              0.137595               0.005166                0.016978
# 2   ...              0.121873               0.008304                0.019507
# 3   ...              0.267772               0.042156                0.002594
# 4   ...              0.179271               0.037254                0.022611
# 5   ...              0.657349               0.000006                0.022750
# 6   ...              0.319031               0.000100                0.022182
# 7   ...              0.234913               0.003735                0.010288
# 8   ...              0.152254               0.063109                0.022165
# 9   ...              0.405818               0.041074                0.021606
# 10  ...              0.185672               0.000029                0.022001
# 11  ...              0.187659               0.004632                0.006990
# 12  ...              0.140345               0.038818                0.011132
# 13  ...              0.292487               0.074218                0.022357
# 14  ...              0.219559               0.107873                0.017890
# 15  ...              0.174516               0.000316                0.011949
# 16  ...              0.234656               0.006770                0.029346
# 17  ...              0.315938               0.053899                0.026557
# 18  ...              0.179043               0.096703                0.081408
# 19  ...              0.288078               0.086224                0.027916
# 20  ...              0.312242               0.000039                0.010192
# 21  ...              0.144332               0.012460                0.006684
# 22  ...              0.082395               0.037501                0.005718
# 23  ...              0.195028               0.144792                0.023223
# 24  ...              0.117655               0.153941                0.009620
# 25  ...              0.473778               0.000011                0.020255
# 26  ...              0.114754               0.004022                0.016637
# 27  ...              0.257707               0.004518                0.014224
# 28  ...              0.305424               0.010145                0.032316
# 29  ...              0.134081               0.051747                0.018461
# ..  ...                   ...                    ...                     ...
# 70  ...              0.213302               0.000079                0.023506
# 71  ...              0.205923               0.012241                0.023697
# 72  ...              0.346048               0.022084                0.027164
# 73  ...              0.224993               0.136011                0.010382
# 74  ...              0.132392               0.160694                0.018147
# 75  ...              0.223571               0.000191                0.032578
# 76  ...              0.108256               0.003804                0.058433
# 77  ...              0.545310               0.001160                0.027419
# 78  ...              0.294074               0.048214                0.129621
# 79  ...              0.165593               0.054108                0.027273
# 80  ...              0.522049               0.000006                0.039510
# 81  ...              0.424922               0.001454                0.040586
# 82  ...              0.123179               0.033664                0.016257
# 83  ...              0.099790               0.076607                0.035904
# 84  ...              0.119681               0.153309                0.042752
# 85  ...              0.191093               0.000013                0.018898
# 86  ...              0.210875               0.003064                0.031242
# 87  ...              0.294964               0.029472                0.074422
# 88  ...              0.236164               0.106450                0.009517
# 89  ...              0.205778               0.182762                0.010753
# 90  ...              0.285359               0.000053                0.028450
# 91  ...              0.256179               0.025092                0.005154
# 92  ...              0.101780               0.121616                0.026204
# 93  ...              0.096599               0.200760                0.018127
# 94  ...              0.140613               0.195304                0.014482
# 95  ...              0.306279               0.000031                0.010328
# 96  ...              0.213143               0.014862                0.026249
# 97  ...              0.106512               0.054115                0.012207
# 98  ...              0.133194               0.216950                0.028389
# 99  ...              0.128299               0.182623                0.013248
#
#     avg_pitch_shift_overlap  pitch_range_kl_div  pitch_range_overlap  \
# 0                  0.799920            0.087234             0.748044
# 1                  0.798308            0.166926             0.708917
# 2                  0.828927            0.053425             0.764101
# 3                  0.798872            0.073521             0.767507
# 4                  0.819122            0.057262             0.785360
# 5                  0.880201            0.035990             0.809867
# 6                  0.886206            0.046518             0.855433
# 7                  0.859342            0.024664             0.862184
# 8                  0.814213            0.051209             0.845444
# 9                  0.817057            0.020489             0.864427
# 10                 0.845467            0.026159             0.836911
# 11                 0.798198            0.032219             0.862379
# 12                 0.805640            0.032713             0.844573
# 13                 0.789127            0.036861             0.836869
# 14                 0.805397            0.074295             0.789564
# 15                 0.833908            0.190303             0.454961
# 16                 0.855182            0.031476             0.654428
# 17                 0.805272            0.012557             0.792255
# 18                 0.791487            0.067267             0.826087
# 19                 0.784720            0.023524             0.811617
# 20                 0.830972            0.174674             0.682066
# 21                 0.842658            0.176125             0.812781
# 22                 0.810357            0.028443             0.836012
# 23                 0.783751            0.029031             0.855260
# 24                 0.804554            0.065749             0.858358
# 25                 0.836687            0.031384             0.808336
# 26                 0.802723            0.048885             0.796217
# 27                 0.825367            0.071027             0.739765
# 28                 0.824041            0.096826             0.734886
# 29                 0.811645            0.047961             0.798314
# ..                      ...                 ...                  ...
# 70                 0.855020            0.164489             0.735002
# 71                 0.786080            0.057210             0.821721
# 72                 0.796190            0.045243             0.835538
# 73                 0.803958            0.074562             0.819101
# 74                 0.796775            0.084536             0.797993
# 75                 0.843598            0.070531             0.749004
# 76                 0.801375            0.042162             0.811210
# 77                 0.767034            0.126529             0.712417
# 78                 0.715086            0.059061             0.757402
# 79                 0.799717            0.090411             0.735887
# 80                 0.811090            0.044786             0.839350
# 81                 0.839981            0.057071             0.858213
# 82                 0.812455            0.037717             0.855617
# 83                 0.797077            0.052090             0.869584
# 84                 0.853083            0.027302             0.843085
# 85                 0.872243            0.056883             0.816406
# 86                 0.844346            0.018742             0.891828
# 87                 0.749224            0.028096             0.863207
# 88                 0.809569            0.063478             0.805463
# 89                 0.801706            0.070933             0.810076
# 90                 0.866038            0.073666             0.569235
# 91                 0.846894            0.028280             0.793967
# 92                 0.796909            0.029847             0.744157
# 93                 0.821262            0.074474             0.765410
# 94                 0.770302            0.037107             0.804117
# 95                 0.885963            0.063124             0.735668
# 96                 0.857396            0.143322             0.810082
# 97                 0.802707            0.036017             0.832071
# 98                 0.812696            0.034157             0.865242
# 99                 0.793113            0.075219             0.828495
#
#     total_pitch_class_histogram_kl_div  total_pitch_class_histogram_overlap  \
# 0                             0.269481                             0.550697
# 1                             0.263322                             0.616435
# 2                             0.135549                             0.633366
# 3                             0.221331                             0.592107
# 4                             0.193686                             0.635182
# 5                             0.175881                             0.525564
# 6                             0.158308                             0.642332
# 7                             0.101608                             0.693508
# 8                             0.220108                             0.684636
# 9                             0.199378                             0.690145
# 10                            0.263351                             0.492964
# 11                            0.193881                             0.609447
# 12                            0.074964                             0.679294
# 13                            0.117737                             0.705113
# 14                            0.142226                             0.702872
# 15                            0.241349                             0.613989
# 16                            0.072162                             0.620395
# 17                            0.095057                             0.626685
# 18                            0.105515                             0.632816
# 19                            0.079264                             0.666632
# 20                            0.353106                             0.640274
# 21                            0.454136                             0.604332
# 22                            0.260582                             0.657572
# 23                            0.492617                             0.653851
# 24                            0.294666                             0.654420
# 25                            0.341151                             0.580972
# 26                            0.209807                             0.618420
# 27                            0.268445                             0.683645
# 28                            0.104721                             0.643693
# 29                            0.114025                             0.690213
# ..                                 ...                                  ...
# 70                            0.493347                             0.602519
# 71                            0.271255                             0.595372
# 72                            0.258586                             0.667699
# 73                            0.416760                             0.597354
# 74                            0.231488                             0.641378
# 75                            0.383705                             0.546516
# 76                            0.302375                             0.610979
# 77                            0.287491                             0.570412
# 78                            0.412602                             0.552384
# 79                            0.142070                             0.653274
# 80                            0.234425                             0.573706
# 81                            0.301141                             0.644717
# 82                            0.098532                             0.693621
# 83                            0.165604                             0.713931
# 84                            0.232037                             0.706327
# 85                            0.207375                             0.555304
# 86                            0.128199                             0.601415
# 87                            0.101560                             0.626317
# 88                            0.182965                             0.697060
# 89                            0.074580                             0.707865
# 90                            0.199702                             0.620879
# 91                            0.111730                             0.647485
# 92                            0.087922                             0.663458
# 93                            0.083306                             0.605325
# 94                            0.088271                             0.671424
# 95                            0.399497                             0.645962
# 96                            0.305210                             0.631173
# 97                            0.464503                             0.626057
# 98                            0.307640                             0.651645
# 99                            0.320716                             0.652041
#
#     note_length_hist_kl_div  note_length_hist_overlap
# 0                  0.090481                  0.447891
# 1                  0.021152                  0.222468
# 2                  0.054807                  0.087404
# 3                  0.028787                  0.100046
# 4                  0.116528                  0.113444
# 5                  0.036305                  0.230142
# 6                  0.031239                  0.038718
# 7                  0.219416                  0.023420
# 8                  0.109915                  0.008799
# 9                  0.164748                  0.030346
# 10                 0.162991                  0.484706
# 11                 0.077641                  0.085046
# 12                 0.089171                  0.006459
# 13                 0.040876                  0.003237
# 14                 0.196890                  0.007361
# 15                 0.073170                  0.500320
# 16                 0.120123                  0.356425
# 17                 0.320055                  0.153968
# 18                 0.113301                  0.008675
# 19                 0.064611                  0.005612
# 20                 0.054798                  0.697363
# 21                 0.061542                  0.448739
# 22                 0.021941                  0.066850
# 23                 0.050719                  0.002638
# 24                 0.142531                  0.000325
# 25                 0.148819                  0.469534
# 26                 0.063546                  0.235934
# 27                 0.021583                  0.162960
# 28                 0.012767                  0.176779
# 29                 0.033151                  0.177165
# ..                      ...                       ...
# 70                 0.094687                  0.662832
# 71                 0.043812                  0.441013
# 72                 0.321804                  0.052078
# 73                 0.079919                  0.000630
# 74                 0.051367                  0.000868
# 75                 0.087973                  0.424465
# 76                 0.029952                  0.193378
# 77                 0.014260                  0.171011
# 78                 0.018334                  0.109087
# 79                 0.015207                  0.089608
# 80                 0.023553                  0.227496
# 81                 0.048658                  0.018318
# 82                 0.227623                  0.027418
# 83                 0.057700                  0.000277
# 84                 0.043598                  0.003677
# 85                 0.256398                  0.432914
# 86                 0.100012                  0.102602
# 87                 0.044303                  0.006740
# 88                 0.098481                  0.000203
# 89                 0.101220                  0.001837
# 90                 0.016587                  0.513800
# 91                 0.253314                  0.333246
# 92                 0.177401                  0.048684
# 93                 0.650759                  0.020522
# 94                 0.095371                  0.003956
# 95                 0.057242                  0.659858
# 96                 0.022518                  0.462751
# 97                 0.186314                  0.087692
# 98                 0.096497                  0.008175
# 99                 0.055934                  0.003794
#
# [100 rows x 29 columns]

# %%
# Plotting phase
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# Read DF
df = pd.read_pickle(path.join(outputdir, 'df_metrics'))

# Get in/out len dimensions
max_in = max(df['in_len'])
max_out = max(df['out_len'])

# Calculate Mean Values for each in/out len combination
suffix = '_avg'
df = df.drop(['out_file', 'primer', 'iteration'], axis=1)
df = df.groupby(['model', 'checkpoint', 'dataset', 'in_len', 'out_len']).mean()
df = df.add_suffix(suffix).reset_index()

# Create Fig Folder
figdir = 'figs'
if not os.path.exists(figdir):
    os.mkdir(figdir)

# Define which plots to make
plots_to_make = (
    [ None
    # , 'time_heatmap_per_model'
    # , 'kldiv_per_model'
    # , 'overlap_per_model'
    # , 'time_per_length'
    # , 'time_ratio_per_length'
    # , 'time_per_length_shared' # TODO: Before doing this, check if there's a correlation

    # , 'time_per_length_shared'
    , 'parallel_coordinates_all_configs'
    # , 'parallel_coordinates_average'
    # , 'parallel_coordinates_best_of_each'
    # , 'heatmap_metric_per_config'
    , 'heatmap_metrics_per_model_config'
    ]
)


# Get Evaluation Metric Names
eval_metrics = ['time' + suffix] + [c for c in list(df.columns) if c.endswith('overlap' + suffix) or c.endswith('kl_div' + suffix)]

overlaps = [m for m in eval_metrics if m.endswith('overlap' + suffix)]
kl_divs  = [m for m in eval_metrics if m.endswith('kl_div' + suffix)]

# Iterate model-checkpoint-dataset tuples
grouping = df.groupby(['model', 'checkpoint', 'dataset'])


# HeatMaps
for (model, checkpoint, dataset), inner_df in grouping:
    # inner_df = inner_df.groupby(['in_len', 'out_len'])
    if 'time_heatmap_per_model' not in plots_to_make: break
    for metric in eval_metrics[:1]:
    # for metric in eval_metrics:
        mdf = inner_df[['in_len', 'out_len', metric]]
        mdf = pd.pivot_table(mdf, values=metric, index=['in_len'], columns=['out_len'], fill_value=0)
        plt.figure()
        plt.title(f'{metric} - {model} {checkpoint} {dataset}')
        sns.heatmap(mdf, cmap='RdYlGn_r', linewidths=0.5, annot=True)
        
        plt.savefig(f'output/images/{figdir}/time-heatmap-{"-".join([model, checkpoint, dataset])}')



# make_line_plots
plot_sets =[
    ('Average Overlaps with Base Dataset', overlaps, 'overlaps'),
    ('Average KL-Divergence against Base Dataset', kl_divs, 'kl_divs'),
    # ('Average Generation Time', ['time_avg'])
]

# TODO: Line Plots
# How does Input Length affect each metric for a model
for (model, checkpoint, dataset), inner_df in grouping:
    if 'kldiv_per_model' not in plots_to_make: break
    in_len_plot = inner_df.loc[inner_df['out_len'] == max(inner_df['out_len'])]
    x = 'in_len'
    if not make_kldiv_plots: continue
    for title, cols, setname in plot_sets:
        fig = plt.figure()
        # print(in_len_plot[[x] + cols])
        in_len_plot[[x] + cols].plot(x=x, colormap='jet', markersize=10)
        plt.title(model)
        plt.legend(title=title, bbox_to_anchor=(1.05, 1), loc='upper left')
        plt.savefig(f'output/images/{figdir}/{"-".join([setname, model, checkpoint, dataset])}', bbox_inches='tight')

for (model, checkpoint, dataset), inner_df in grouping:
    if 'overlap_per_model' not in plots_to_make: break
    out_len_plot = inner_df.loc[inner_df['in_len'] == max(inner_df['in_len'])]
    x = 'out_len'
    if not make_overlap_plots: continue    
    for title, cols, setname in plot_sets:
        plt.figure()
        # print(out_len_plot[[x] + cols])
        out_len_plot[[x] + cols].plot(x=x, colormap='jet', markersize=10)
        plt.title(model)
        plt.legend(title=title, bbox_to_anchor=(1.05, 1), loc='upper left')
        plt.savefig(f'output/images/{figdir}/{"-".join([setname, model, checkpoint, dataset])}', bbox_inches='tight')
    
# model, checkpoint

plots = ['in_len', 'out_len']
for l in plots:
    if 'metrics_per_each_len' not in plots_to_make: break
    cols = ['time_avg']
    if not make_time_plots: continue
    counterpart = [i for i in plots if i != l][0]
    for i in df[counterpart].unique():
        time_plot = df.loc[df[counterpart] == i]
        time_plot = time_plot[['model', 'checkpoint', l] + cols]
        time_plot = pd.pivot_table(time_plot, values=cols, index=[l], columns=['model', 'checkpoint'], fill_value=0)
        # print(time_plot)
        plt.figure()
        time_plot.plot()
        plt.legend(title=f'{title} ({counterpart} = {i})', bbox_to_anchor=(1.05, 1), loc='upper left')
        # plt.legend(title=f'Average Time for {counterpart} = {i}', bbox_to_anchor=(1.05, 1), loc='upper left')

# TODO: Move to Definitions
# Column names to filter out
ignore_words = ['std', 'avg', 'kl', 'div', 'overlap']
def filter_metric_names(list_):
    return ['_'.join([x for x in name.split('_') if x not in ignore_words]) for name in list_]

# PLOT: Heatmap By Configuration
if 'heatmap_metric_per_config' in plots_to_make:
    df_by_config = df.copy()
    df_by_config = df_by_config[df_by_config['model'] != 'performance_rnn']
    df_by_config['config'] = df_by_config["in_len"].astype(str) + '_' + df_by_config["out_len"].astype(str)
    configlen = len(df_by_config['config'].unique())
    df_by_config['time_avg'] = df_by_config['time_avg'] / (iterations * configlen)
    df_by_config = df_by_config.drop(columns=['in_len','out_len'])
    df_by_config = df_by_config.groupby('config')
    df_by_config = df_by_config.aggregate('mean')
    for i, metricset in enumerate([overlaps, kl_divs]):
        a = plt.figure(dpi=150,figsize=(14,10))
        inner_df = df_by_config[metricset]
        inner_df.columns = filter_metric_names(metricset)
        metricset = filter_metric_names(metricset)
        sns.heatmap(inner_df[metricset], cmap='Blues', annot=True)
        plt.tight_layout()
        plt.savefig(f'output/images/heatmap_{["overlaps","kl_divs"][i]}.png')
        plt.show()

# Parallel Coordinates Plot
from pandas.plotting import parallel_coordinates

# TODO: Move to Definitions
colors = [ None
    , '#2f4b7c'
    , '#665191'
    , '#a05195'
    , '#d45087'
    , '#f95d6a'
    , '#ff7c43'
    , '#ffa600'
][1:]

colors = ["#c3839c", "#72b2a4", "#c9ae89", "#c15e5e", "#565155"]

# Make KL-Distance / Overlap Multiplot from dataframe
from pandas.plotting import parallel_coordinates
def make_kl_overlap_multiplot(dataframe,
    output='test.png',
    title="No Title",
    label_kl_divs="No KL Divs Label",
    label_overlaps="No Overlap Label"):
    metricsets = [ None
                 , (overlaps, label_overlaps)
                 , (kl_divs, label_kl_divs)
                 ][1:]

    # Create Multiplot
    a = plt.figure(dpi=150,figsize=(8,6))
    fig, axs = plt.subplots(2, dpi=150,figsize=(10,8),sharex='col', sharey='row')
    gs = fig.add_gridspec(2, 1, hspace=0, wspace=0)
    plt.suptitle(title)
    plt.xticks(rotation=90)

    

    # Create Subplots
    for i, (metricset, legend) in enumerate(metricsets):
        
        # Prepare Dataframe (Filter Columns)
        inner_df = dataframe.copy()
        subset_df = inner_df[metricset + ['model']]
        subset_df.columns = filter_metric_names(subset_df.columns)
        inner_df.columns = filter_metric_names(inner_df.columns)
        metricset = filter_metric_names(metricset)

        # Calculate plot
        final_df = pd.DataFrame(subset_df, columns=metricset)
        final_df = pd.concat([final_df, subset_df['model']], axis=1)
        # plots.append()
        parallel_coordinates(final_df, 'model', colors=colors, ax=axs[i])
        axs[i].legend(title=legend, bbox_to_anchor=(1.05, 1), loc='upper left')
        plt.tight_layout()

    plt.savefig(f'output/images/{output}')
    plt.show()


# Parallel Coordinates: All Configurations
if 'parallel_coordinates_all_configs' in plots_to_make:
    df_by_config = df.copy()
    make_kl_overlap_multiplot(df_by_config
    , output="metrics_per_model_all_configs.png"
    , title="Metrics per Model (All Configurations)"
    , label_overlaps="Metric KL-Distance per Model"
    , label_kl_divs="Metric Overlap pe r Model"
    )

# Parallel Coordinates: Average
if 'parallel_coordinates_average' in plots_to_make:
    df_by_model = df.copy()
    df_by_model = df_by_model.groupby(('model')).mean().reset_index()
    make_kl_overlap_multiplot(df_by_model
    , output="metrics_per_model_average.png"
    , title="Average Metrics per Model"
    , label_overlaps="Average Metric Overlap per Model"
    , label_kl_divs="Average Metric KL-Distance per Model"
    )


# TODO
# Parallel Coordinates (Best of each (ornette) vs baseline)
if 'parallel_coordinates_best_of_each' in plots_to_make:
    print('')

# Heatmap: Metric mean per config per model
if 'heatmap_metrics_per_model_config' in plots_to_make:
    # Copy and prepare DataFrame
    df_by_config = df.copy()
    df_by_config['config'] = df_by_config["in_len"].astype(str) + '_' + df_by_config["out_len"].astype(str)
    df_by_config.drop(columns=['in_len','out_len'])
    # df_by_config.drop(columns=['in_len','out_len','iteration'])
    df_by_config = df_by_config.groupby(['model','checkpoint','config']).mean().reset_index()

    # Get Subset DFs
    col_metrics = df_by_config.columns
    col_kl_divs  = [x for x in col_metrics if x.endswith('kl_div_avg')]
    col_overlaps = [x for x in col_metrics if x.endswith('overlap_avg')]

    # Calculate KL Divs and Overlap mean and std per model config
    loc_kldivs = df_by_config[['model'] + col_kl_divs].loc[: , "bar_pitch_class_histogram_kl_div_avg":"note_length_hist_kl_div_avg"]
    df_by_config['kl_mean'] = loc_kldivs.mean(axis=1)
    df_by_config['kl_std'] = loc_kldivs.std(axis=1)
    loc_overlaps = df_by_config[['model'] + col_overlaps].loc[: , "bar_pitch_class_histogram_overlap_avg":"note_length_hist_overlap_avg"]
    df_by_config['overlap_mean'] = loc_overlaps.mean(axis=1)
    df_by_config['overlap_std'] = loc_overlaps.std(axis=1)
    df_by_config = df_by_config[['model','checkpoint','config','overlap_mean','overlap_std','kl_mean','kl_std']]


    subplots = (
        [ ('overlap_mean', 'overlap_std', 'Overlap Mean')
        , ('kl_mean'     , 'kl_std'     , 'KL-Divergence Mean')
        ]
    )

    # Generate Plot
    plt.figure()
    fig, axs = plt.subplots(2, figsize=(28,8), sharex='col', sharey='row', dpi=150)
    fig.suptitle('Impact of Input/Output Length Pair over Key Metrics')
    gs = fig.add_gridspec(2, 1, hspace=0, wspace=0)
    tmp_df = df_by_config.copy()
    
    for i, (column_mean, column_std, title) in enumerate(subplots):
        # tmp_df[column_std] = '(±' + tmp_df[column_std].astype(str) + ')'
        cmap = ['Greens', 'Greens_r'][i]
        
        # Straight
        mean_df = pd.pivot_table(tmp_df, values=column_mean, index=['model', 'checkpoint'], columns=['config'])
        std_df = pd.pivot_table(tmp_df, values=column_std, index=['model', 'checkpoint'], columns=['config'])

        ax = axs[i]
        ax.set_title(title)
        sns.heatmap(mean_df, annot=True,   cmap=cmap, linewidths=0.5, ax=ax, annot_kws={'va':'top'})
        sns.heatmap(mean_df, annot=std_df, cmap=cmap, linewidths=0.5, ax=ax, annot_kws={'va':'bottom'}, cbar=False)

    plt.savefig('output/images/metric_mean_std_config_heatmap.png')
    plt.show()

print(f'Done! Generated plots: {plots_to_make}')
# Out:
# Done! Generated plots: [None, 'parallel_coordinates_all_configs', 'heatmap_metrics_per_model_config']

# %%
# print(df)
# print(output)
# print(a_test)
# print(cols_gen)
# cols_gen = [ "model", "checkpoint", "dataset", "primer", "iteration", "out_file", "time", "in_len", "out_len" ]

# a_test = pd.DataFrame(output, columns=cols_gen)
# a_test.head()
# a_test.to_pickle('./output/temp_rl_df')
print(output)
# Out:
# ', 'bach10', '04-ChristeDuBeistand.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-0-5-2-04-ChristeDuBeistand.mid', 12.836111840908416, 5, 2], ['melody_rnn', 'lookback_rnn', 'bach10', '04-ChristeDuBeistand.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-1-5-2-04-ChristeDuBeistand.mid', 12.836111840908416, 5, 2], ['melody_rnn', 'lookback_rnn', 'bach10', '04-ChristeDuBeistand.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-2-5-2-04-ChristeDuBeistand.mid', 12.836111840908416, 5, 2], ['melody_rnn', 'lookback_rnn', 'bach10', '04-ChristeDuBeistand.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-3-5-2-04-ChristeDuBeistand.mid', 12.836111840908416, 5, 2], ['melody_rnn', 'lookback_rnn', 'bach10', '02-AchLiebenChristen.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-0-5-3-02-AchLiebenChristen.mid', 20.422546992078424, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '02-AchLiebenChristen.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-1-5-3-02-AchLiebenChristen.mid', 20.422546992078424, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '02-AchLiebenChristen.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-2-5-3-02-AchLiebenChristen.mid', 20.422546992078424, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '02-AchLiebenChristen.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-3-5-3-02-AchLiebenChristen.mid', 20.422546992078424, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '01-AchGottundHerr.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-0-5-3-01-AchGottundHerr.mid', 18.102101798984222, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '01-AchGottundHerr.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-1-5-3-01-AchGottundHerr.mid', 18.102101798984222, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '01-AchGottundHerr.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-2-5-3-01-AchGottundHerr.mid', 18.102101798984222, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '01-AchGottundHerr.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-3-5-3-01-AchGottundHerr.mid', 18.102101798984222, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '07-HerrGott.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-0-5-3-07-HerrGott.mid', 13.549424209049903, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '07-HerrGott.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-1-5-3-07-HerrGott.mid', 13.549424209049903, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '07-HerrGott.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-2-5-3-07-HerrGott.mid', 13.549424209049903, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '07-HerrGott.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-3-5-3-07-HerrGott.mid', 13.549424209049903, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '08-FuerDeinenThron.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-0-5-3-08-FuerDeinenThron.mid', 12.46028912300244, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '08-FuerDeinenThron.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-1-5-3-08-FuerDeinenThron.mid', 12.46028912300244, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '08-FuerDeinenThron.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-2-5-3-08-FuerDeinenThron.mid', 12.46028912300244, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '08-FuerDeinenThron.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-3-5-3-08-FuerDeinenThron.mid', 12.46028912300244, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '05-DieNacht.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-0-5-3-05-DieNacht.mid', 19.04216298297979, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '05-DieNacht.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-1-5-3-05-DieNacht.mid', 19.04216298297979, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '05-DieNacht.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-2-5-3-05-DieNacht.mid', 19.04216298297979, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '05-DieNacht.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-3-5-3-05-DieNacht.mid', 19.04216298297979, 5, 3], ['melody_rnn', 'lookback_rnn', 'bach10', '09-Jesus.mid', 4, '2021-08-09-0/melody_rnn-lookback_rnn-0-5-3-09-Jesus.mid', 17.033785269013606, 5 ...

# %%
import pandas as pd 

merger_columns = ['model', 'checkpoint', 'dataset']

def get_mean_metrics(df_input):
    df_ = df_input.copy()
    df_['config'] = df_["in_len"].astype(str) + '_' + df_["out_len"].astype(str)
    df_.drop(columns=['in_len', 'out_len', 'iteration'])
    df_ = df_.groupby(['model','checkpoint','config']).mean().reset_index()
    return df_

df_generation = pd.read_pickle('output/df_metrics_generation')
col_metrics = df_generation.columns
col_overlaps = [x for x in col_metrics if x.endswith('overlap')]
loc_overlaps = df_generation[['model'] + col_overlaps].loc[: , "bar_pitch_class_histogram_overlap":"note_length_hist_overlap"]
df_generation['overlap_mean'] = loc_overlaps.mean(axis=1)
df_generation['overlap_mean_gen'] = loc_overlaps.mean(axis=1)

df_baseline = pd.read_pickle('output/df_metrics_baseline')


# Merge Datasets
# FIXME: this is an outer join which may affect the mean
df = df_generation.merge(df_baseline, how='outer', on=merger_columns, suffixes=("_gen", "_baseline"))
df.drop(columns=['iteration', 'time'])


# df_by_config['overlap_mean_gen'] = loc_overlaps.mean(axis=1)
# df_by_config['overlap_std'] = loc_overlaps.std(axis=1)

# Create Indexers
df['config'] = df["in_len"].astype(str) + '_' + df["out_len"].astype(str)
df['model_config'] = df['model_config'] = df[['model', 'checkpoint', 'config']].apply(lambda row: ':'.join(row.values.astype(str)), axis=1)
df = df.groupby(['model', 'model_config']).mean().reset_index()

# Get best overlap mean
df = df.loc[df.reset_index().groupby(['model','model_config'])['overlap_mean_gen'].idxmax()]

# Drop columns which won't be plotted
df = df.drop(columns=['overlap_mean_gen', 'time', 'iteration'])


# df = df.melt(id_vars=["model_config"], var_name="metric", value_name="score").dropna()

# Split by Baseline/Generated
# maxes['source'] = maxes['metric'].astype(str).str.contains('baseline').apply(lambda x: 'Baseline' if x == True else 'Generated')

# Split by metric type
# maxes['metric_type'] = maxes['metric'].astype(str).str.contains(subplots[0][0]).apply(lambda x: 'Overlap' if x == True else 'KL-Divergence')

# df.head()
# print()
# df.describe()
#print(df_generation.describe())

df.plot()
# Out:
# <AxesSubplot:>

# %%
# Create 'config' column, group by model:checkpoint:config
df_by_config = pd.read_pickle(os.path.join(outputdir, 'df_metrics_generation'))
df_by_config['config'] = df_by_config["in_len"].astype(str) + '_' + df_by_config["out_len"].astype(str)
df_by_config.drop(columns=['in_len','out_len','iteration'])
# print(df_by_config.head())
df_by_config = df_by_config.groupby(['model','checkpoint','config']).mean().reset_index()
# df_by_config.loc[df_by_config['config'] == '1_2'].head()

# Get Subset DFs
col_metrics = df_by_config.columns
col_kl_divs  = [x for x in col_metrics if x.endswith('kl_div')]
col_overlaps = [x for x in col_metrics if x.endswith('overlap')]

# Calculate KL Divs mean and std per model config
loc_kldivs = df_by_config[['model'] + col_kl_divs].loc[: , "bar_pitch_class_histogram_kl_div":"note_length_hist_kl_div"]
df_by_config['kl_mean'] = loc_kldivs.mean(axis=1)
df_by_config['kl_std'] = loc_kldivs.std(axis=1)
loc_overlaps = df_by_config[['model'] + col_overlaps].loc[: , "bar_pitch_class_histogram_overlap":"note_length_hist_overlap"]
df_by_config['overlap_mean'] = loc_overlaps.mean(axis=1)
df_by_config['overlap_std'] = loc_overlaps.std(axis=1)
df_mean_metrics = df_by_config

print(df_mean_metrics)
